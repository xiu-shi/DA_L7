# %%
#IMPORTING LIBRARIES
import pandas as pd
import statistics as stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_excel('/Users/eupirate/Documents/DA_L7_CCT/DA_L7/WK3_25_Sep_1_Oct/Exercise_1_Descriptive_Stats.xlsx')

# %%
dataset
# Out:
#     Customer ID      Entity        Name   Surname  Age at time of purchase  \
# 0         C0028  Individual     Madalyn    Mercer                     19.0
# 1         C0027  Individual        Lara  Carrillo                     22.0
# 2         C0112  Individual     Donavan   Flowers                     22.0
# 3         C0160  Individual      Darien    Dorsey                     22.0
# 4         C0014  Individual  Alessandra     Perry                     25.0
# ..          ...         ...         ...       ...                      ...
# 190       C0174        Firm     Marleez        Co                      NaN
# 191       C0174        Firm     Marleez        Co                      NaN
# 192       C0174        Firm     Marleez        Co                      NaN
# 193       C0174        Firm     Marleez        Co                      NaN
# 194       C0174        Firm     Marleez        Co                      NaN
#
# ...

# %%
dataset.describe()

# %%
#Missing values

dataset.isnull().values.any()

# %%
dataset.isnull().sum()

# %%
ax = sns.histplot(dataset.Age, kde=True, color ='pink')
ax.set(xlabel='Age', ylabel='Customers', title ='Age at the time of purchasing')

# %%
ax = sns.histplot(dataset.Satisfaction, kde=True, color ='red')
ax.set(xlabel='Satisfaction Level', ylabel='Customers', title ='Customer Satisfaction Level')

# %%
dataset.Country.value_counts()

# %%
value_counts = dataset['Country'].value_counts()
relative_frequencies = value_counts/len(dataset)

# %%
relative_frequencies

# %%
#WE CREATE A TABLE

table = pd.DataFrame({'Country': value_counts.index,
                     'Frequency': value_counts.values,
                     'Relative Frequency': relative_frequencies.values})

# %%
table
