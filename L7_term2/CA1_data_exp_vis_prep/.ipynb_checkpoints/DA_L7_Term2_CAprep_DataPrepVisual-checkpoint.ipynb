# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
from scipy import stats
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import CategoricalNB

# %%
# original mushroom.csv have been saved as source of truth, created a copy mush.csv for analysis
mushroom_raw_df = pd.read_csv("/Users/eupirate/Desktop/CA_data_exp_visdual/mush.csv")

# %%
mushroom_raw_df.head()
# Out:
#   Mushroom ID Cap Shape Cap Color Gill Size Stalk Shape  Habitat  Edibility  \
# 0           1    sunken     brown    narrow    tapering   leaves     edible
# 1           ?    convex     brown    narrow    tapering    urban     edible
# 2           3      flat     brown     broad   enlarging  grasses     edible
# 3           4    sunken      gray    narrow    tapering        ?  poisonous
# 4           5      flat       red         ?   enlarging    urban     edible
#
#   Market Demand Spore Print Color Population  ... Stalk Surface Below Ring  \
# 0             1            orange   abundant  ...                    silky
# 1             2             brown    several  ...                    scaly
# 2             8            yellow  scattered  ...                        ?
# 3             4            orange  scattered  ...                    scaly
# 4             7             brown    several  ...                  fibrous
#
#   Stalk Color Above Ring Stalk Color Below Ring  Veil Type Veil Color  \
# 0                  white                  brown  universal     orange
# 1                   pink                  white  universal      white
# 2                   gray                 orange    partial     orange
# 3                   gray                 orange  universal     yellow
# 4                 orange                  white    partial      white
#
#    Growth Rate Inspection Date Incubation date Temperature Measurement
# 0  0.973096463      03/07/2021      03/02/2021          49           C
# 1            ?      03/05/2023      03/04/2023          13           F
# 2  1.977619113      01/08/2022      01/04/2022          10           C
# 3  2.272762762      02/10/2023      02/02/2023          22           C
# 4  0.718873785      01/09/2023      01/04/2023           9           C
#
# [5 rows x 24 columns]

# %%
mushroom_raw_df.describe()
# Out:
#        Temperature
# count  1000.000000
# mean     14.666000
# std       8.698742
# min       0.000000
# 25%       7.000000
# 50%      15.000000
# 75%      22.000000
# max      49.000000

# %%
# mushroom_raw_categorical ["Cap Shape","Cap Color","Gill Size","Stalk Shape",
#                            "Habitat","Edibility","Spore Print Color","Population",
#                            "Odor","Bruising","Ring Type","Stalk Surface Above Ring","Stalk Surface Below Ring",
#                            "Stalk Color Above Ring","Stalk Color Below Ring","Veil Type","Veil Color",
#                            "Measurement"]

# mushroom_raw_num["Mushroom ID","Market Demand","Bruising","Growth Rate","Temperature"]
# mushroom_raw_date["Inspection Date","Incubation date",]

# %%
# mushroom categorical columns
mushroom_raw_df.replace("?",np.nan,inplace=True)

# Include Edibility Column
'''
df_bool = mushroom_raw_df[["Cap Shape","Cap Color","Gill Size","Stalk Shape",
                            "Habitat","Edibility","Spore Print Color","Population",
                            "Odor","Bruising","Ring Type","Stalk Surface Above Ring","Stalk Surface Below Ring",
                            "Stalk Color Above Ring","Stalk Color Below Ring","Veil Type","Veil Color",
                            "Measurement"]].isna()
#print(df_bool)
df_bool.isnull().sum()
'''


# Exclude Edibility Column
df_bool = mushroom_raw_df[["Cap Shape","Cap Color","Gill Size","Stalk Shape",
                            "Habitat","Spore Print Color","Population",
                            "Odor","Bruising","Ring Type","Stalk Surface Above Ring","Stalk Surface Below Ring",
                            "Stalk Color Above Ring","Stalk Color Below Ring","Veil Type","Veil Color",
                            "Measurement"]].isna()
#print(df_bool)
df_bool.isnull().sum()
# Out:
# Cap Shape                   0
# Cap Color                   0
# Gill Size                   0
# Stalk Shape                 0
# Habitat                     0
# Spore Print Color           0
# Population                  0
# Odor                        0
# Bruising                    0
# Ring Type                   0
# Stalk Surface Above Ring    0
# Stalk Surface Below Ring    0
# Stalk Color Above Ring      0
# Stalk Color Below Ring      0
# Veil Type                   0
# Veil Color                  0
# Measurement                 0
# dtype: int64

# %%
# Ensuring Edibility NaN isn't replaced, will handle seprately
# mushroom_raw_df.head(21)

# %%
# include NaN, run describe()
mushroom_raw_df.describe()
# Out:
#        Temperature
# count  1000.000000
# mean     14.666000
# std       8.698742
# min       0.000000
# 25%       7.000000
# 50%      15.000000
# 75%      22.000000
# max      49.000000

# %%
# now we drop all rows with any NaN values
mushroom_drop_NaN = mushroom_raw_df.dropna()
mushroom_drop_NaN.describe()
# Out:
#        Temperature
# count   119.000000
# mean     14.848739
# std       8.999660
# min       0.000000
# 25%       8.000000
# 50%      14.000000
# 75%      23.000000
# max      49.000000

# %% [markdown]
# # Before dropping NaN, we had 1000 rows of data, after dropped NaN, we only have 119 rows of data to work with, which is not a good representation of the dataset. I think we should explore other approaches to replace with NaN values.

# %% [markdown]
# # Identified those columns are mushroom's feature categorical columns, we choose to apply mode to replace NaN with the most common value of a column

# %% [markdown]
# # With a better understanding of the data, Edibility column is excluded from the mode replacement, as we don't want to misclassify or make inaccurate predictions, we want to ensure predict mushroom edibility safely.

# %%
# Exclude Edibility Column, it will be handled seprately soon.
for column in mushroom_raw_df.select_dtypes(include="object").columns:
    if column != "Edibility":
        mushroom_raw_df[column].fillna(mushroom_raw_df[column].mode()[0], inplace=True)
#print(mushroom_raw_df)
mushroom_raw_df.head(21)
#mushroom_raw_df.describe()
# Out:
#    Mushroom ID Cap Shape Cap Color Gill Size Stalk Shape  Habitat  Edibility  \
# 0            1    sunken     brown    narrow    tapering   leaves     edible
# 1            1    convex     brown    narrow    tapering    urban     edible
# 2            3      flat     brown     broad   enlarging  grasses     edible
# 3            4    sunken      gray    narrow    tapering    urban  poisonous
# 4            5      flat       red    narrow   enlarging    urban     edible
# 5            6      bell      gray    narrow    tapering  grasses  poisonous
# 6            7      flat     brown     broad    tapering    woods        NaN
# 7            8    sunken       red    narrow   enlarging    urban        NaN
# 8            9   conical    yellow    narrow   enlarging  grasses     edible
# 9           10      bell      gray     broad    tapering    paths  poisonous
# 10          11    sunken     white     broad   enlarging    urban        NaN
# 11          12   conical     brown     broad   enlarging   leaves        NaN
# 12           1      bell    yellow     broad   enlarging   leaves     edible
# 13          14      bell     brown    narrow   enlarging    urban  poisonous
# 14          15   conical      gray    narrow   enlarging    woods     edible
# 15           1    convex     brown    narrow   enlarging    urban     edible
# 16          17      flat      gray     broad    tapering    urban        NaN
# 17          18   conical     brown    narrow   enlarging    urban  poisonous
# 18          19    convex       red     broad    tapering    urban  poisonous
# 19          20   conical     brown    narrow    tapering    urban     edible
# 20          21    sunken      gray    narrow    tapering    urban     edible
#
#    Market Demand Spore Print Color Population  ... Stalk Surface Below Ring  \
# 0              1            orange   abundant  ...                    silky
# 1              2             brown    several  ...                    scaly
# 2              8            yellow  scattered  ...                    silky
# 3              4            orange  scattered  ...                    scaly
# 4              7             brown    several  ...                  fibrous
# 5              6            yellow    several  ...                    silky
# 6              5            yellow  scattered  ...                    scaly
# 7              3            yellow    several  ...                    silky
# 8              7            yellow   solitary  ...                  fibrous
# 9              3             white   numerous  ...                    scaly
# 10             3             black   numerous  ...                  fibrous
# 11             2             brown  scattered  ...                    scaly
# 12             8             brown   numerous  ...                    silky
# 13             9             brown   numerous  ...                    silky
# 14             5             brown   numerous  ...                  fibrous
# 15             3            yellow   solitary  ...                  fibrous
# 16            10            orange   solitary  ...                  fibrous
# 17             1             brown   numerous  ...                   smooth
# 18             3             black   solitary  ...                   smooth
# 19            10             brown  scattered  ...                  fibrous
# 20             3             black  scattered  ...                    silky
#
#    Stalk Color Above Ring Stalk Color Below Ring  Veil Type Veil Color  \
# 0                   white                  brown  universal     orange
# 1                    pink                  white  universal      white
# 2                    gray                 orange    partial     orange
# 3                    gray                 orange  universal     yellow
# 4                  orange                  white    partial      white
# 5                  orange                  white  universal     orange
# 6                   white                  white  universal      white
# 7                    gray                 orange    partial     yellow
# 8                   brown                   gray  universal     orange
# 9                   white                  white  universal     yellow
# 10                   gray                   pink  universal      brown
# 11                   gray                   gray    partial     yellow
# 12                   gray                   pink  universal     yellow
# 13                  white                   gray    partial      white
# 14                  white                   gray  universal      white
# 15                  brown                  brown    partial      white
# 16                  white                  brown    partial     yellow
# 17                  brown                   gray  universal      brown
# 18                   pink                   gray  universal     yellow
# 19                 orange                   gray    partial      brown
# 20                  brown                  brown    partial      white
#
#     Growth Rate Inspection Date Incubation date Temperature Measurement
# 0   0.973096463      03/07/2021      03/02/2021          49           C
# 1   0.502267005      03/05/2023      03/04/2023          13           F
# 2   1.977619113      01/08/2022      01/04/2022          10           C
# 3   2.272762762      02/10/2023      02/02/2023          22           C
# 4   0.718873785      01/09/2023      01/04/2023           9           C
# 5   14.02415593      04/11/2023      04/05/2023          21           C
# 6   4.320348762      02/08/2023      02/04/2023          13           C
# 7   1.450596518      02/07/2023      02/05/2023           2           C
# 8   3.545415336      01/07/2023      01/01/2023           8           C
# 9   3.866757255      04/05/2023      04/01/2023          10           C
# 10  9.468676774      03/12/2023      03/05/2023          26           C
# 11  3.544817568      05/06/2023      05/01/2023           6           C
# 12  4.471316648      01/02/2022      01/02/2022          18           C
# 13  1.154902118      03/09/2023      03/02/2023          20           C
# 14  2.144728044      05/02/2023      05/02/2023          16           C
# 15  3.392187959      02/11/2023      02/02/2023          13           C
# 16  4.745231837      04/07/2022      04/03/2022          23           C
# 17  4.373511264      05/11/2020      05/05/2020          20           C
# 18  0.502267005      02/05/2023      02/05/2023          12           C
# 19  2.806382872      03/08/2023      03/01/2023          23           C
# 20  0.972110245      04/10/2023      04/04/2023          21           C
#
# [21 rows x 24 columns]

# %% [markdown]
# # By applying mode to replace NaN, we have successfully preserved 1000 rows in count, mean remained at 14.666, std at 8.698742 as original raw data set.

# %%
# We need to address column Mushroom ID's indexing sequence - starting from 1
mushroom_raw_df.index = range(1,len(mushroom_raw_df)+1)
mushroom_raw_df["Mushroom ID"] = mushroom_raw_df.index
print(mushroom_raw_df.index)

#mushroom_raw_df.head()

mushroom_raw_df.describe()
# Out:
# RangeIndex(start=1, stop=1001, step=1)
#        Mushroom ID  Temperature
# count  1000.000000  1000.000000
# mean    500.500000    14.666000
# std     288.819436     8.698742
# min       1.000000     0.000000
# 25%     250.750000     7.000000
# 50%     500.500000    15.000000
# 75%     750.250000    22.000000
# max    1000.000000    49.000000

# %%
# Let's verify Market Demand ? has been replaced with mode, 
#print(mushroom_raw_df[["Market Demand"]].head(30))
mushroom_raw_df[["Market Demand"]].isnull().sum()
# Out:
# Market Demand    0
# dtype: int64

# %%
print(mushroom_raw_df.isnull().sum())
#mushroom_raw_df.head(21)
#mushroom_raw_df.describe()
# Out:
# Mushroom ID                   0
# Cap Shape                     0
# Cap Color                     0
# Gill Size                     0
# Stalk Shape                   0
# Habitat                       0
# Edibility                   113
# Market Demand                 0
# Spore Print Color             0
# Population                    0
# Odor                          0
# Bruising                      0
# Ring Type                     0
# Stalk Surface Above Ring      0
# Stalk Surface Below Ring      0
# Stalk Color Above Ring        0
# Stalk Color Below Ring        0
# Veil Type                     0
# Veil Color                    0
# Growth Rate                   0
# Inspection Date               0
# Incubation date               0
# Temperature                   0
# Measurement                   0
# dtype: int64

# %%
# We convert Bruising column's Yes to 1 and No to 0 
mushroom_raw_df["Bruising"] = mushroom_raw_df["Bruising"].replace({"Yes": 1, "No": 0})
# Then we verify Bruising columns Yes or No has been converted to 1 and 0
#print(mushroom_raw_df[["Bruising"]].head(21))
mushroom_raw_df["Bruising"].isnull().sum()
# Out:
# 0

# %%
#print(mushroom_raw_df["Growth Rate"])
mushroom_raw_df["Growth Rate"].isnull().sum()
#mushroom_raw_df.head()
mushroom_raw_df.describe()
# Out:
#        Mushroom ID     Bruising  Temperature
# count  1000.000000  1000.000000  1000.000000
# mean    500.500000     0.559000    14.666000
# std     288.819436     0.496755     8.698742
# min       1.000000     0.000000     0.000000
# 25%     250.750000     0.000000     7.000000
# 50%     500.500000     1.000000    15.000000
# 75%     750.250000     1.000000    22.000000
# max    1000.000000     1.000000    49.000000

# %%
# Now, let's handle Edibility Column, taking conditional imputation approach about the missing values in Edibility column
