# %%
# 2nd version
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#from sklearn.impute import KNNImputer, SimpleImputer

# %%
mushroom_raw_df = pd.read_csv("/Users/eupirate/Desktop/CA_data_exp_visdual/mush.csv")
mushroom_raw_df.head(10)
# Out:
#   Mushroom ID Cap Shape Cap Color Gill Size Stalk Shape  Habitat  Edibility  \
# 0           1    sunken     brown    narrow    tapering   leaves     edible
# 1           ?    convex     brown    narrow    tapering    urban     edible
# 2           3      flat     brown     broad   enlarging  grasses     edible
# 3           4    sunken      gray    narrow    tapering        ?  poisonous
# 4           5      flat       red         ?   enlarging    urban     edible
# 5           6      bell         ?    narrow    tapering  grasses  poisonous
# 6           7      flat     brown     broad    tapering    woods          ?
# 7           8    sunken       red    narrow   enlarging    urban          ?
# 8           9         ?    yellow    narrow           ?  grasses     edible
# 9          10      bell         ?     broad    tapering    paths  poisonous
#
#   Market Demand Spore Print Color Population  ... Stalk Surface Below Ring  \
# 0             1            orange   abundant  ...                    silky
# 1             2             brown    several  ...                    scaly
# 2             8            yellow  scattered  ...                        ?
# 3             4            orange  scattered  ...                    scaly
# 4             7             brown    several  ...                  fibrous
# 5             6            yellow    several  ...                        ?
# 6             5            yellow  scattered  ...                    scaly
# 7             3            yellow    several  ...                        ?
# 8             7            yellow   solitary  ...                  fibrous
# 9             3             white          ?  ...                    scaly
#
#   Stalk Color Above Ring Stalk Color Below Ring  Veil Type Veil Color  \
# 0                  white                  brown  universal     orange
# 1                   pink                  white  universal      white
# 2                   gray                 orange    partial     orange
# 3                   gray                 orange  universal     yellow
# 4                 orange                  white    partial      white
# 5                 orange                  white  universal     orange
# 6                  white                  white  universal      white
# 7                   gray                 orange    partial     yellow
# 8                  brown                   gray          ?     orange
# 9                  white                  white  universal     yellow
#
#    Growth Rate Inspection Date Incubation date Temperature Measurement
# 0  0.973096463      03/07/2021      03/02/2021          49           C
# 1            ?      03/05/2023      03/04/2023          13           F
# 2  1.977619113      01/08/2022      01/04/2022          10           C
# 3  2.272762762      02/10/2023      02/02/2023          22           C
# 4  0.718873785      01/09/2023      01/04/2023           9           C
# 5  14.02415593      04/11/2023      04/05/2023          21           C
# 6  4.320348762      02/08/2023      02/04/2023          13           C
# 7  1.450596518      02/07/2023      02/05/2023           2           C
# 8  3.545415336      01/07/2023      01/01/2023           8           C
# 9  3.866757255      04/05/2023      04/01/2023          10           C
#
# [10 rows x 24 columns]

# %%
# Handle Mushroom ID column indexing
mushroom_raw_df["Mushroom ID"] = mushroom_raw_df.index+1
#print(mushroom_raw_df.iloc[:16])

# %%
# mushroom categorical columns
mushroom_raw_df.replace("?",np.nan,inplace=True)

# Include Edibility Column
'''
df_bool = mushroom_raw_df[["Cap Shape","Cap Color","Gill Size","Stalk Shape",
                            "Habitat","Edibility","Spore Print Color","Population",
                            "Odor","Bruising","Ring Type","Stalk Surface Above Ring","Stalk Surface Below Ring",
                            "Stalk Color Above Ring","Stalk Color Below Ring","Veil Type","Veil Color",
                            "Measurement"]].isna()
#print(df_bool)
df_bool.isnull().sum()
'''


# Exclude Edibility Column
df_bool = mushroom_raw_df[["Cap Shape","Cap Color","Gill Size","Stalk Shape",
                            "Habitat","Spore Print Color","Population",
                            "Odor","Bruising","Ring Type","Stalk Surface Above Ring","Stalk Surface Below Ring",
                            "Stalk Color Above Ring","Stalk Color Below Ring","Veil Type","Veil Color",
                            "Measurement"]].isna()
#print(df_bool)
df_bool.isnull().sum()
# Out:
# Cap Shape                   0
# Cap Color                   0
# Gill Size                   0
# Stalk Shape                 0
# Habitat                     0
# Spore Print Color           0
# Population                  0
# Odor                        0
# Bruising                    0
# Ring Type                   0
# Stalk Surface Above Ring    0
# Stalk Surface Below Ring    0
# Stalk Color Above Ring      0
# Stalk Color Below Ring      0
# Veil Type                   0
# Veil Color                  0
# Measurement                 0
# dtype: int64

# %%
# include NaN, run describe()
mushroom_raw_df.describe()
# Out:
#        Mushroom ID  Temperature
# count  1000.000000  1000.000000
# mean    500.500000    14.666000
# std     288.819436     8.698742
# min       1.000000     0.000000
# 25%     250.750000     7.000000
# 50%     500.500000    15.000000
# 75%     750.250000    22.000000
# max    1000.000000    49.000000

# %%
# now we drop all rows with any NaN values
mushroom_drop_NaN = mushroom_raw_df.dropna()
mushroom_drop_NaN.describe()
# Out:
#        Mushroom ID  Temperature
# count   131.000000   131.000000
# mean    524.580153    14.519084
# std     298.132184     8.966048
# min       1.000000     0.000000
# 25%     233.000000     7.500000
# 50%     544.000000    13.000000
# 75%     789.000000    22.500000
# max     995.000000    49.000000

# %% [markdown]
# # Before dropping NaN, we had 1000 rows of data, after dropped NaN, we only have 119 rows of data to work with, which is not a good representation of the dataset. I think we should explore other approaches to replace with NaN values.

# %% [markdown]
# # Identified those columns are mushroom's feature categorical columns, we choose to apply mode to replace NaN with the most common value of a column

# %% [markdown]
# # With a better understanding of the data, Edibility column is excluded from the mode replacement, as we don't want to misclassify or make inaccurate predictions, we want to ensure predict mushroom edibility safely.

# %%
# Exclude Edibility Column, it will be handled seprately soon.
for column in mushroom_raw_df.select_dtypes(include="object").columns:
    if column != "Edibility":
        mushroom_raw_df[column].fillna(mushroom_raw_df[column].mode()[0], inplace=True)
#print(mushroom_raw_df)
#mushroom_raw_df.head(21)
#mushroom_raw_df.describe()

# %%
# make a copy of df - which excluded 'Edibility' column
mushroom_raw_df_tr=mushroom_raw_df.copy()
mushroom_raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mushroom ID               1000 non-null   int64
#  1   Cap Shape                 1000 non-null   object
#  2   Cap Color                 1000 non-null   object
#  3   Gill Size                 1000 non-null   object
#  4   Stalk Shape               1000 non-null   object
#  5   Habitat                   1000 non-null   object
#  6   Edibility                 887 non-null    object
#  7   Market Demand             1000 non-null   object
#  8   Spore Print Color         1000 non-null   object
#  9   Population                1000 non-null   object
#  10  Odor                      1000 non-null   object
#  11  Bruising                  1000 non-null   object
#  12  Ring Type                 1000 non-null   object
#  13  Stalk Surface Above Ring  1000 non-null   object
#  14  Stalk Surface Below Ring  1000 non-null   object
#  15  Stalk Color Above Ring    1000 non-null   object
#  16  Stalk Color Below Ring    1000 non-null   object
#  17  Veil Type                 1000 non-null   object
#  18  Veil Color                1000 non-null   object
#  19  Growth Rate               1000 non-null   object
#  20  Inspection Date           1000 non-null   object
#  21  Incubation date           1000 non-null   object
#  22  Temperature               1000 non-null   int64
#  23  Measurement               1000 non-null   object
# dtypes: int64(2), object(22)
# memory usage: 187.6+ KB

# %%
# create a treated 'Edibility_Tr1' column hardcode "NotDefined"
'''
mushroom_raw_df_tr=mushroom_raw_df.copy()
mushroom_raw_df_tr["Edibility_Tr1"]=mushroom_raw_df_tr["Edibility"].fillna("NotDefined_1")
mushroom_raw_df_tr.info()
mushroom_raw_df_tr.head(21)
'''
# Out:
# '\nmushroom_raw_df_tr=mushroom_raw_df.copy()\nmushroom_raw_df_tr["Edibility_Tr1"]=mushroom_raw_df_tr["Edibility"].fillna("NotDefined_1")\nmushroom_raw_df_tr.info()\nmushroom_raw_df_tr.head(21)\n'

# %%
# Appy SimpleImputer
from sklearn.impute import SimpleImputer

mushroom_raw_df_tr=mushroom_raw_df.copy()

# Create "NotDefined" with SimpleImputer
imp=SimpleImputer(strategy="constant",fill_value="NotDefined_2")

# create a treated 'Edibility_Tr2' column by using SimpleImputer fit_transform function
mushroom_raw_df_tr[["Edibility_Tr2"]]=imp.fit_transform(mushroom_raw_df_tr[["Edibility"]])
mushroom_raw_df_tr[["Edibility_Tr2"]]

#mushroom_raw_df_tr.head(30)
# Out:
#     Edibility_Tr2
# 0          edible
# 1          edible
# 2          edible
# 3       poisonous
# 4          edible
# ..            ...
# 995     poisonous
# 996        edible
# 997        edible
# 998        edible
# 999  NotDefined_2
#
# [1000 rows x 1 columns]

# %%
# Ensure Mushroom ID are indexed correctly

# mushroom_raw_df_tr['Mushroom ID'].isnull().sum()


# Ensure "Temperature" are converted to C 

#

# ----------------------

# Assuming 'Mushroom ID' is used directly or set as an index, and 'Measurement' indicates the unit
# First, ensure 'Mushroom ID' is suitable for use as an index or reference
# ----------------------
mushroom_raw_df_tr=mushroom_raw_df.copy()

mushroom_raw_df_tr["Mushroom ID"]=pd.to_numeric(mushroom_raw_df_tr["Mushroom ID"], errors="coerce")

# Identify rows with F temperatures and convert them
f_rows = mushroom_raw_df_tr['Measurement'] == 'F'
mushroom_raw_df_tr.loc[f_rows,"Temperature"] = (mushroom_raw_df_tr.loc[f_rows,"Temperature"]-32)*5/9

# Update the Measurement column to C for these rows
mushroom_raw_df_tr.loc[f_rows,"Measurement"] = "C"

# If 'Mushroom ID' should be an index
mushroom_raw_df_tr.set_index("Mushroom ID",inplace=True)

# Quickly check all the F values have been converted to C values
temps_index=mushroom_raw_df_tr.loc[[87,88,99,111,141],"Temperature"]

#print(temps_index)

mushroom_raw_df_tr.head(50)
# ----------------------


# Edibility_Tr2"

# Strong relationship columns ["Growth Rate","Inspection Date","Temperature","Incubation date","Habitat"]
# Out:
# /var/folders/zn/1r2fyj917_n2qngrf527q0rr0000gn/T/ipykernel_38173/477408784.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-10.55555556  -6.66666667 -17.22222222 -11.11111111 -17.77777778
#   -9.44444444  -5.          -8.33333333 -14.44444444 -16.66666667
#   -3.88888889 -17.22222222 -11.11111111  -4.44444444  -5.55555556
#   -8.88888889 -11.66666667 -16.66666667  -4.44444444  -9.44444444
#   -4.44444444 -11.66666667 -11.11111111  -9.44444444 -13.33333333
#   -6.11111111 -14.44444444  -2.22222222  -4.44444444  -7.77777778
#   -3.33333333 -15.55555556 -16.11111111]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   mushroom_raw_df_tr.loc[f_rows,"Temperature"] = (mushroom_raw_df_tr.loc[f_rows,"Temperature"]-32)*5/9
#             Cap Shape Cap Color Gill Size Stalk Shape  Habitat  Edibility  \
# Mushroom ID
# 1              sunken     brown    narrow    tapering   leaves     edible
# 2              convex     brown    narrow    tapering    urban     edible
# 3                flat     brown     broad   enlarging  grasses     edible
# 4              sunken      gray    narrow    tapering    urban  poisonous
# 5                flat       red    narrow   enlarging    urban     edible
# 6                bell      gray    narrow    tapering  grasses  poisonous
# 7                flat     brown     broad    tapering    woods        NaN
# 8              sunken       red    narrow   enlarging    urban        NaN
# 9             conical    yellow    narrow   enlarging  grasses     edible
# 10               bell      gray     broad    tapering    paths  poisonous
# 11             sunken     white     broad   enlarging    urban        NaN
# 12            conical     brown     broad   enlarging   leaves        NaN
# 13               bell    yellow     broad   enlarging   leaves     edible
# 14               bell     brown    narrow   enlarging    urban  poisonous
# 15            conical      gray    narrow   enlarging    woods     edible
# 16             convex     brown    narrow   enlarging    urban     edible
# 17               flat      gray     broad    tapering    urban        NaN
# 18            conical     brown    narrow   enlarging    urban  poisonous
# 19             convex       red     broad    tapering    urban  poisonous
# 20            conical     brown    narrow    tapering    urban     edible
# 21             sunken      gray    narrow    tapering    urban     edible
# 22             convex       red    narrow   enlarging    urban     edible
# 23            conical     brown     broad   enlarging    urban  poisonous
# 24               flat    yellow    narrow   enlarging    urban     edible
# 25            conical     brown     broad   enlarging    paths  poisonous
# 26             sunken       red     broad   enlarging    urban     edible
# 27             convex       red     broad    tapering    woods     edible
# 28             sunken      gray     broad   enlarging  grasses  poisonous
# 29            conical     brown    narrow   enlarging  grasses  poisonous
# 30            conical      gray    narrow   enlarging    woods  poisonous
# 31            conical       red     broad   enlarging    paths     edible
# 32            conical      gray    narrow   enlarging    woods     edible
# 33             convex     white    narrow   enlarging    urban     edible
# 34            conical       red    narrow   enlarging  grasses        NaN
# 35               bell      gray    narrow   enlarging    urban  poisonous
# 36               bell      gray    narrow   enlarging   leaves     edible
# 37             sunken    yellow     broad    tapering    urban  poisonous
# 38             sunken      gray    narrow   enlarging    urban  poisonous
# 39               bell      gray     broad    tapering    urban        NaN
# 40            conical     white    narrow   enlarging    paths     edible
# 41            conical     white    narrow    tapering  grasses        NaN
# 42             convex      gray     broad   enlarging    urban        NaN
# 43               bell      gray     broad   enlarging    urban     edible
# 44             convex    yellow    narrow    tapering    paths        NaN
# 45             convex      gray    narrow   enlarging    urban     edible
# 46            conical      gray    narrow   enlarging    urban  poisonous
# 47            conical     white     broad   enlarging    urban  poisonous
# 48            conical    yellow     broad    tapering    woods  poisonous
# 49             convex    yellow     broad    tapering    urban  poisonous
# 50            conical     white     broad   enlarging    paths     edible
#
#             Market Demand Spore Print Color Population      Odor  ...  \
# Mushroom ID                                                       ...
# 1                       1            orange   abundant     musty  ...
# 2                       2             brown    several      foul  ...
# 3                       8            yellow  scattered     musty  ...
# 4                       4            orange  scattered  creosote  ...
# 5                       7             brown    several    almond  ...
# 6                       6            yellow    several     anise  ...
# 7                       5            yellow  scattered      foul  ...
# 8                       3            yellow    several    almond  ...
# 9                       7            yellow   solitary    almond  ...
# 10                      3             white   numerous     musty  ...
# 11                      3             black   numerous  creosote  ...
# 12                      2             brown  scattered     musty  ...
# 13                      8             brown   numerous    almond  ...
# 14                      9             brown   numerous      foul  ...
# 15                      5             brown   numerous  creosote  ...
# 16                      3            yellow   solitary  creosote  ...
# 17                     10            orange   solitary     anise  ...
# 18                      1             brown   numerous      foul  ...
# 19                      3             black   solitary     anise  ...
# 20                     10             brown  scattered  creosote  ...
# 21                      3             black  scattered     anise  ...
# 22                      4            orange   numerous      foul  ...
# 23                      4             black   numerous    almond  ...
# 24                      5             brown  scattered     anise  ...
# 25                      6             white   solitary     anise  ...
# 26                      2             white  scattered    almond  ...
# 27                      2            yellow   solitary      foul  ...
# 28                      1             brown   numerous    almond  ...
# 29                      1             brown    several    almond  ...
# 30                     10             white   abundant  creosote  ...
# 31                      3            orange   numerous    almond  ...
# 32                      3             white   solitary     anise  ...
# 33                      1             white    several     musty  ...
# 34                      6            orange   solitary    almond  ...
# 35                      4            yellow   numerous     musty  ...
# 36                      1             brown   abundant    almond  ...
# 37                      9             brown    several     musty  ...
# 38                      9             brown   abundant  creosote  ...
# 39                      7             brown   numerous    almond  ...
# 40                      9             black   solitary    almond  ...
# 41                      5             black   abundant    almond  ...
# 42                      4             white   numerous      foul  ...
# 43                      1             white   abundant    almond  ...
# 44                      3            yellow   solitary    almond  ...
# 45                      2            orange   solitary  creosote  ...
# 46                      2             white   numerous  creosote  ...
# 47                      7            orange   abundant     musty  ...
# 48                      7             black   solitary    almond  ...
# 49                      8             brown    several  creosote  ...
# 50                      4            yellow    several    almond  ...
#
#             Stalk Surface Below Ring Stalk Color Above Ring  \
# Mushroom ID
# 1                              silky                  white
# 2                              scaly                   pink
# 3                              silky                   gray
# 4                              scaly                   gray
# 5                            fibrous                 orange
# 6                              silky                 orange
# 7                              scaly                  white
# 8                              silky                   gray
# 9                            fibrous                  brown
# 10                             scaly                  white
# 11                           fibrous                   gray
# 12                             scaly                   gray
# 13                             silky                   gray
# 14                             silky                  white
# 15                           fibrous                  white
# 16                           fibrous                  brown
# 17                           fibrous                  white
# 18                            smooth                  brown
# 19                            smooth                   pink
# 20                           fibrous                 orange
# 21                             silky                  brown
# 22                             silky                 orange
# 23                           fibrous                   pink
# 24                            smooth                 orange
# 25                             scaly                 orange
# 26                             silky                  white
# 27                             scaly                  brown
# 28                           fibrous                   gray
# 29                             scaly                   gray
# 30                           fibrous                  white
# 31                            smooth                  brown
# 32                             silky                 orange
# 33                            smooth                   gray
# 34                             scaly                 orange
# 35                             silky                   pink
# 36                             scaly                   pink
# 37                             silky                   pink
# 38                             scaly                  white
# 39                             silky                  brown
# 40                             silky                   pink
# 41                           fibrous                   gray
# 42                            smooth                  white
# 43                             scaly                   pink
# 44                             silky                  brown
# 45                           fibrous                   gray
# 46                             silky                   pink
# 47                             silky                   pink
# 48                            smooth                   gray
# 49                             silky                   gray
# 50                             silky                  white
#
#             Stalk Color Below Ring  Veil Type Veil Color  Growth Rate  \
# Mushroom ID
# 1                            brown  universal     orange  0.973096463
# 2                            white  universal      white  0.502267005
# 3                           orange    partial     orange  1.977619113
# 4                           orange  universal     yellow  2.272762762
# 5                            white    partial      white  0.718873785
# 6                            white  universal     orange  14.02415593
# 7                            white  universal      white  4.320348762
# 8                           orange    partial     yellow  1.450596518
# 9                             gray  universal     orange  3.545415336
# 10                           white  universal     yellow  3.866757255
# 11                            pink  universal      brown  9.468676774
# 12                            gray    partial     yellow  3.544817568
# 13                            pink  universal     yellow  4.471316648
# 14                            gray    partial      white  1.154902118
# 15                            gray  universal      white  2.144728044
# 16                           brown    partial      white  3.392187959
# 17                           brown    partial     yellow  4.745231837
# 18                            gray  universal      brown  4.373511264
# 19                            gray  universal     yellow  0.502267005
# 20                            gray    partial      brown  2.806382872
# 21                           brown    partial      white  0.972110245
# 22                          orange    partial      white  3.978356469
# 23                            gray  universal     orange  1.661912017
# 24                            pink    partial     yellow  1.556834306
# 25                            gray    partial      brown  3.089211748
# 26                           brown    partial      white  0.502267005
# 27                            gray    partial     yellow  1.592207281
# 28                           brown  universal      brown  3.702939206
# 29                           brown  universal     orange  4.534452789
# 30                           brown    partial     yellow  0.502267005
# 31                            pink  universal     orange  0.518327751
# 32                            pink  universal      white  11.56745366
# 33                           white    partial     yellow  3.143234818
# 34                           white  universal      brown  3.269644388
# 35                           white  universal      white  4.910980688
# 36                            gray    partial      brown   4.32343949
# 37                            pink  universal      white  4.741876533
# 38                           white  universal     yellow  3.440629756
# 39                          orange  universal     yellow  1.837350078
# 40                            gray  universal     orange  1.745118584
# 41                           white  universal      white  2.581496612
# 42                           white  universal     orange  4.552947763
# 43                           brown  universal      white  3.467514155
# 44                            gray    partial     orange   4.41296737
# 45                          orange  universal      brown  1.893680876
# 46                            gray    partial     yellow  0.996436986
# 47                            pink    partial      white  4.833548413
# 48                           white    partial      white  2.533547657
# 49                           white    partial      white  3.116886795
# 50                          orange  universal     yellow  4.227525285
#
#             Inspection Date Incubation date Temperature Measurement
# Mushroom ID
# 1                03/07/2021      03/02/2021   49.000000           C
# 2                03/05/2023      03/04/2023  -10.555556           C
# 3                01/08/2022      01/04/2022   10.000000           C
# 4                02/10/2023      02/02/2023   22.000000           C
# 5                01/09/2023      01/04/2023    9.000000           C
# 6                04/11/2023      04/05/2023   21.000000           C
# 7                02/08/2023      02/04/2023   13.000000           C
# 8                02/07/2023      02/05/2023    2.000000           C
# 9                01/07/2023      01/01/2023    8.000000           C
# 10               04/05/2023      04/01/2023   10.000000           C
# 11               03/12/2023      03/05/2023   26.000000           C
# 12               05/06/2023      05/01/2023    6.000000           C
# 13               01/02/2022      01/02/2022   18.000000           C
# 14               03/09/2023      03/02/2023   20.000000           C
# 15               05/02/2023      05/02/2023   16.000000           C
# 16               02/11/2023      02/02/2023   13.000000           C
# 17               04/07/2022      04/03/2022   23.000000           C
# 18               05/11/2020      05/05/2020   20.000000           C
# 19               02/05/2023      02/05/2023   12.000000           C
# 20               03/08/2023      03/01/2023   23.000000           C
# 21               04/10/2023      04/04/2023   21.000000           C
# 22               03/07/2023      03/03/2023    1.000000           C
# 23               04/09/2023      04/01/2023    3.000000           C
# 24               02/08/2023      02/05/2023    6.000000           C
# 25               04/07/2023      04/01/2023   11.000000           C
# 26               02/07/2023      02/02/2023   26.000000           C
# 27                4/14/2023      04/05/2023    5.000000           C
# 28               05/01/2023      05/01/2023   28.000000           C
# 29               02/04/2023      02/04/2023    3.000000           C
# 30               03/04/2023      03/04/2023   11.000000           C
# 31               04/06/2023      04/01/2023   13.000000           C
# 32               04/06/2022      04/01/2022   21.000000           C
# 33               03/07/2023      03/03/2023    4.000000           C
# 34                3/14/2023      03/05/2023   28.000000           C
# 35               02/02/2023      02/01/2023   23.000000           C
# 36               01/10/2023      01/04/2023    0.000000           C
# 37               02/05/2023      02/03/2023   12.000000           C
# 38               01/09/2023      01/04/2023   25.000000           C
# 39               01/01/2023      01/01/2023    2.000000           C
# 40               04/12/2022      04/04/2022    2.000000           C
# 41                3/13/2023      03/05/2023   12.000000           C
# 42               04/10/2023      04/01/2023   25.000000           C
# 43               03/05/2023      03/05/2023    9.000000           C
# 44               05/10/2022      05/02/2022   25.000000           C
# 45               01/06/2023      01/04/2023    5.000000           C
# 46               05/08/2023      05/04/2023    9.000000           C
# 47               05/02/2023      05/01/2023   19.000000           C
# 48               03/11/2023      03/03/2023   16.000000           C
# 49               03/06/2023      03/01/2023   18.000000           C
# 50               04/03/2023      04/02/2023   20.000000           C
#
# [50 rows x 23 columns]
