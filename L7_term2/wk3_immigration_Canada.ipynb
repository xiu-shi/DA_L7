# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
dataset = pd.read_excel("/Users/eupirate/Documents/DA_L7/L7_term2/wk3_canada.xlsx", 
                        sheet_name = "Canada by Citizenship",
                        skiprows = range(20)
                       )
dataset.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# 2  3623  4005  5393  4752  4325  3774  4331
# 3     0     0     0     0     0     0     0
# 4     1     0     0     0     0     1     1
#
# [5 rows x 43 columns]

# %%
# we remove the columns that will not be used

dataset.drop(["AREA","REG","DEV"], axis=1, inplace = True)
dataset.head()
# Out:
#          Type    Coverage          OdName AreaName          RegName  \
# 0  Immigrants  Foreigners     Afghanistan     Asia    Southern Asia
# 1  Immigrants  Foreigners         Albania   Europe  Southern Europe
# 2  Immigrants  Foreigners         Algeria   Africa  Northern Africa
# 3  Immigrants  Foreigners  American Samoa  Oceania        Polynesia
# 4  Immigrants  Foreigners         Andorra   Europe  Southern Europe
#
#               DevName  1980  1981  1982  1983  ...  2004  2005  2006  2007  \
# 0  Developing regions    16    39    39    47  ...  2978  3436  3009  2652
# 1   Developed regions     1     0     0     0  ...  1450  1223   856   702
# 2  Developing regions    80    67    71    69  ...  3616  3626  4807  3623
# 3  Developing regions     0     1     0     0  ...     0     0     1     0
# 4   Developed regions     0     0     0     0  ...     0     0     1     1
#
#    2008  2009  2010  2011  2012  2013
# 0  2111  1746  1758  2203  2635  2004
# 1   560   716   561   539   620   603
# 2  4005  5393  4752  4325  3774  4331
# 3     0     0     0     0     0     0
# 4     0     0     0     0     1     1
#
# [5 rows x 40 columns]

# %%
dataset['Total'] = dataset.iloc[:, 9:].sum(axis=1)

#dataset['Total'] = dataset.sum(axis=1)
dataset.head()
# Out:
#          Type    Coverage          OdName AreaName          RegName  \
# 0  Immigrants  Foreigners     Afghanistan     Asia    Southern Asia
# 1  Immigrants  Foreigners         Albania   Europe  Southern Europe
# 2  Immigrants  Foreigners         Algeria   Africa  Northern Africa
# 3  Immigrants  Foreigners  American Samoa  Oceania        Polynesia
# 4  Immigrants  Foreigners         Andorra   Europe  Southern Europe
#
#               DevName  1980  1981  1982  1983  ...  2005  2006  2007  2008  \
# 0  Developing regions    16    39    39    47  ...  3436  3009  2652  2111
# 1   Developed regions     1     0     0     0  ...  1223   856   702   560
# 2  Developing regions    80    67    71    69  ...  3626  4807  3623  4005
# 3  Developing regions     0     1     0     0  ...     0     1     0     0
# 4   Developed regions     0     0     0     0  ...     0     1     1     0
#
#    2009  2010  2011  2012  2013  Total
# 0  1746  1758  2203  2635  2004  58545
# 1   716   561   539   620   603  15698
# 2  5393  4752  4325  3774  4331  69221
# 3     0     0     0     0     0      5
# 4     0     0     0     1     1     15
#
# [5 rows x 41 columns]

# %%
# we set an index to locate the data by country

dataset.set_index("OdName", inplace = True)

# %%
# we want to check Haiti

print(dataset.loc["Haiti"])
# Out:
# Type                             Immigrants
# Coverage                         Foreigners
# AreaName    Latin America and the Caribbean
# RegName                           Caribbean
# DevName                  Developing regions
# 1980                                   1666
# 1981                                   3692
# 1982                                   3498
# 1983                                   2860
# 1984                                   1418
# 1985                                   1321
# 1986                                   1753
# 1987                                   2132
# 1988                                   1829
# 1989                                   2377
# 1990                                   2379
# 1991                                   2829
# 1992                                   2399
# 1993                                   3655
# 1994                                   2100
# 1995                                   2014
# 1996                                   1955
# 1997                                   1645
# 1998                                   1295
# 1999                                   1439
# 2000                                   1631
# 2001                                   2433
# 2002                                   2174
# 2003                                   1930
# 2004                                   1652
# 2005                                   1682
# 2006                                   1619
# 2007                                   1598
# 2008                                   2491
# 2009                                   2080
# 2010                                   4744
# 2011                                   6503
# 2012                                   5868
# 2013                                   4152
# Total                                 75957
# Name: Haiti, dtype: object

# %%
# we want to check 2013

print(dataset.loc["Haiti",2013])
# Out:
# 4152

# %%
# conver year to string to start plotting

dataset.columns = list(map(str,dataset.columns)) 
[print(type(x)) for x in dataset.columns.values]
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# new we visualize the data, we'll see X = Year, Y = No. of immigrants 
# we set a range of years from 1980 to 2013 ( 2013 + 1 = 2014 )

years = list(map(str,range(1980,2014)))

# %%
# we want to see No. of immigratns in Haiti from 1980 to 2013

dataset.loc["Haiti", years].plot(kind = "line", color = "red")
plt.title("Immigrants from Haiti")
plt.ylabel("Number of Immigrants")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
# we want to add text to mention the earthquake

# we want to see No. of immigratns in Haiti from 1980 to 2013

dataset.loc["Haiti", years].plot(kind = "line", color = "red")
plt.title("Immigrants from Haiti")
plt.ylabel("Number of Immigrants")
plt.xlabel("Year")
plt.text( 20, 6000, "Earthquake 2010")
# Out:
# Text(20, 6000, 'Earthquake 2010')

# %%
# we want to compare Haiti vs Argentina

dataset.loc["Haiti", years].plot(kind = "line", color = "red")
dataset.loc["Argentina", years].plot(kind = "line", color = "blue")
plt.title("Immigrants from Haiti vs Argentina")
plt.ylabel("Number of Immigrants")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
# we want to compare Haiti vs Argentina

dataset.loc["Haiti", years].plot(kind = "line", color = "red")
dataset.loc["Argentina", years].plot(kind = "line", color = "blue")
plt.title("Immigrants from Haiti vs Argentina")
plt.ylabel("Number of Immigrants")
plt.xlabel("Year")
plt.legend(["Haiti","Argentina"])
plt.text( 20, 6000, "Earthquake 2010")
# Out:
# Text(20, 6000, 'Earthquake 2010')

# %% [markdown]
# # Area plot

# %%
# we organise the dta from the largest to smallest

dataset.sort_values(["Total"],ascending = False, axis = 0, inplace = True)
dataset.head()
# Out:
#                                                           Type    Coverage  \
# OdName
# Total                                               Immigrants        Both
# India                                               Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# Philippines                                         Immigrants  Foreigners
# United Kingdom of Great Britain and Northern Ir...  Immigrants  Foreigners
#
#                                                    AreaName  \
# OdName
# Total                                                 World
# India                                                  Asia
# China                                                  Asia
# Philippines                                            Asia
# United Kingdom of Great Britain and Northern Ir...   Europe
#
#                                                                RegName  \
# OdName
# Total                                                            World
# India                                                    Southern Asia
# China                                                     Eastern Asia
# Philippines                                         South-Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
#
#                                                                DevName  \
# OdName
# Total                                                            World
# India                                               Developing regions
# China                                               Developing regions
# Philippines                                         Developing regions
# United Kingdom of Great Britain and Northern Ir...   Developed regions
#
#                                                       1980    1981    1982  \
# OdName
# Total                                               143137  128641  121175
# India                                                 8880    8670    8147
# China                                                 5123    6682    3308
# Philippines                                           6051    5921    5249
# United Kingdom of Great Britain and Northern Ir...   22045   24796   20620
#
#                                                      1983   1984  ...    2005  \
# OdName                                                            ...
# Total                                               89185  88272  ...  262242
# India                                                7338   5704  ...   36210
# China                                                1863   1527  ...   42584
# Philippines                                          4562   3801  ...   18139
# United Kingdom of Great Britain and Northern Ir...  10015  10170  ...    7258
#
#                                                       2006    2007    2008  \
# OdName
# Total                                               251640  236753  247244
# India                                                33848   28742   28261
# China                                                33518   27642   30037
# Philippines                                          18400   19837   24887
# United Kingdom of Great Britain and Northern Ir...    7140    8216    8979
#
#                                                       2009    2010    2011  \
# OdName
# Total                                               252170  280687  248748
# India                                                29456   34235   27509
# China                                                29622   30391   28502
# Philippines                                          28573   38617   36765
# United Kingdom of Great Britain and Northern Ir...    8876    8724    6204
#
#                                                       2012    2013    Total
# OdName
# Total                                               257903  259021  6531259
# India                                                30933   33087   666207
# China                                                33024   34129   644849
# Philippines                                          34315   29544   494170
# United Kingdom of Great Britain and Northern Ir...    6195    5827   484039
#
# [5 rows x 40 columns]

# %%
# we select the top 5 countries to create the area plot

top5 = dataset[years].head(5).transpose()
top5.head()
# Out:
# OdName   Total  India  China  Philippines  \
# 1980    143137   8880   5123         6051
# 1981    128641   8670   6682         5921
# 1982    121175   8147   3308         5249
# 1983     89185   7338   1863         4562
# 1984     88272   5704   1527         3801
#
# OdName  United Kingdom of Great Britain and Northern Ireland
# 1980                                                22045
# 1981                                                24796
# 1982                                                20620
# 1983                                                10015
# 1984                                                10170

# %%
# we create the plot

top5.plot(kind = "area",
         alpha = 0.25,
         figsize = (20,10),)
plt.title("Immigrants Top 5 Countries")
plt.ylabel("Number of Immigrants")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')
