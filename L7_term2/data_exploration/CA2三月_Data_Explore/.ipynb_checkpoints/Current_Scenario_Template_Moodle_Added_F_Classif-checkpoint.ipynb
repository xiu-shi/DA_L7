# %%
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

###  handlin missing  data
from sklearn.impute import SimpleImputer

### libraries for feature selection 
from scipy.stats import chi2_contingency

#### added f_classif here as the target value could be a categorical encoded.. :)
from sklearn.feature_selection import chi2, f_regression, f_classif
from sklearn.feature_selection import SelectKBest

# %%
### Research missingno library
# !pip install missingno
import missingno as msno

# %%
df_ml = pd.read_csv("/Users/eupirate/Desktop/CCT/CA2三月_Data_Explore/CA2 - Data Exploration amp Preparation - Instructions-20240329/ML_Data_R_copy.csv", na_values   = "?")

# %%
### Research: 
### MCAR (Missing Completely at Random)
### MAR (Missing at Random)
### MNAR (Missing Not at Random)
# For missing values... Missing at Random (MAR), MCAR, MNAR.. see if you find these types on the dataframe

# Load original copy dataset which contains missing data
df = pd.read_csv("/Users/eupirate/Desktop/CCT/CA2三月_Data_Explore/CA2 - Data Exploration amp Preparation - Instructions-20240329/ML_Data_R_copy.csv")

### Visualize the missingness pattern
### The white lines 
msno.matrix(df)

### by leveraging missingno library, we identified there are white lines in the 'Delivery Date' column contains missing data
### they are not uniformly distributed, it seems to be concentrated in specific areas of the data
### as our analysis continue, we'll discover the randomness
# Out:
# <Axes: >

# %%
df_ml_dropna=df_ml.dropna()

# %%
df_ml_dropna.head(10)
# Out:
#     ID_Record  ID  Entry ID  Strategic Sale Destination  Group        Date  \
# 2           3  66     18072               0          NL      2   6/26/2021
# 3           4  17     18181               1          US      2  08/02/2021
# 4           5  55     18335               1          DE      7   9/13/2021
# 5           6  66     18378               0          NL      2   9/27/2021
# 6           7  66     18397               0          NL      2  10/04/2021
# 7           8  66     18397               0          NL      2  10/04/2021
# 8           9  55     18462               1          DE     23  10/25/2021
# 9          10  55     18462               1          DE     23  10/25/2021
# 10         11  65     18470               1          NL      7  10/25/2021
# 11         12  65     18470               1          NL      7  10/25/2021
#
#     Sequence  Product  Qty  ... Logistic Partner  Deposit Replacement  \
# 2         77     4440   30  ...               C6       L9          NO
# 3         11     4440   62  ...               C2       L2          NO
# 4          2     4481  250  ...               C6       L9          NO
# 5         31     4440  500  ...               C6       L9          NO
# 6          1     4452   99  ...               C6       L9          NO
# 7          1     4452   19  ...               C6       L9          NO
# 8          4     4492  500  ...               C6       L9          NO
# 9          4     4492  100  ...               C6       L9          NO
# 10         2     4481   16  ...              C13      L13          NO
# 11         2     4481   20  ...              C13      L13          NO
#
#    Market Demand Quarter  Week Strateg Prod Strat Customer ABC Customer Group
# 2              3  2022Q4     1            0             No   C           3986
# 3              1  2022Q3     9            0             No   C            684
# 4              3  2022Q4    12            0             No   C            521
# 5              3  2022Q1     4            0             No   C           3986
# 6              3  2022Q3    10            0             No   C           3986
# 7              3  2022Q3    10            0             No   C           3986
# 8              3  2022Q3     5            0             No   C            521
# 9              3  2022Q3     5            0             No   C            521
# 10             3  2022Q3    10            0             No   C            720
# 11             3  2022Q3     6            0             No   C            720
#
# [10 rows x 27 columns]

# %%
#df_ml.info()
df_ml_dropna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14836 entries, 2 to 15886
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_Record         14836 non-null  int64
#  1   ID                14836 non-null  int64
#  2   Entry ID          14836 non-null  int64
#  3   Strategic Sale    14836 non-null  int64
#  4   Destination       14836 non-null  object
#  5   Group             14836 non-null  int64
#  6   Date              14836 non-null  object
#  7   Sequence          14836 non-null  int64
#  8   Product           14836 non-null  int64
#  9   Qty               14836 non-null  int64
#  10  Total Value       14836 non-null  object
#  11  Unit Price        14836 non-null  float64
#  12  Planned Date      14836 non-null  object
#  13  Delivered Date    14836 non-null  object
#  14  TYPE              14836 non-null  object
#  15  Qty Delivered     14836 non-null  float64
#  16  Order Source      14836 non-null  object
#  17  Logistic Partner  14836 non-null  object
#  18  Deposit           14836 non-null  object
#  19  Replacement       14836 non-null  object
#  20  Market Demand     14836 non-null  int64
#  21  Quarter           14836 non-null  object
#  22  Week              14836 non-null  int64
#  23  Strateg Prod      14836 non-null  int64
#  24  Strat Customer    14836 non-null  object
#  25  ABC               14836 non-null  object
#  26  Customer Group    14836 non-null  int64
# dtypes: float64(2), int64(12), object(13)
# memory usage: 3.2+ MB

# %%
#df_ml_tr = df_ml.copy()
df_ml_tr = df_ml_dropna.copy()

# %%
df_ml_tr.isnull().sum()
# Out:
# ID_Record           0
# ID                  0
# Entry ID            0
# Strategic Sale      0
# Destination         0
# Group               0
# Date                0
# Sequence            0
# Product             0
# Qty                 0
# Total Value         0
# Unit Price          0
# Planned Date        0
# Delivered Date      0
# TYPE                0
# Qty Delivered       0
# Order Source        0
# Logistic Partner    0
# Deposit             0
# Replacement         0
# Market Demand       0
# Quarter             0
# Week                0
# Strateg Prod        0
# Strat Customer      0
# ABC                 0
# Customer Group      0
# dtype: int64

# %%
#### CLEANING DATA - DROPPING ALL Null data
df_ml_dropna.to_csv("/Users/eupirate/Desktop/CCT/CA2三月_Data_Explore/CA2 - Data Exploration amp Preparation - Instructions-20240329/ML_Data_nadrop.csv", index=False)
# Export missing values dropped data to a new CSV file 'ML_Data_nadrop.csv'
## from this point, we'll be using "df_ml_dropna" for our analysis

# %%
### describe the dataset and visualise - descriptive statistics 
df_ml_dropna.describe
# Out:
# <bound method NDFrame.describe of        ID_Record  ID  Entry ID  Strategic Sale Destination  Group        Date  \
# 2              3  66     18072               0          NL      2   6/26/2021
# 3              4  17     18181               1          US      2  08/02/2021
# 4              5  55     18335               1          DE      7   9/13/2021
# 5              6  66     18378               0          NL      2   9/27/2021
# 6              7  66     18397               0          NL      2  10/04/2021
# ...          ...  ..       ...             ...         ...    ...         ...
# 15882      15883  65     19580               1          NL     21  12/04/2022
# 15883      15884  65     19580               1          NL     23  12/04/2022
# 15884      15885  17     19580               1          US     21  12/04/2022
# 15885      15886  17     19580               1          US     25  12/04/2022
# 15886      15887  17     19580               1          US     21  12/04/2022
#
#        Sequence  Product  Qty  ... Logistic Partner  Deposit Replacement  \
# 2            77     4440   30  ...               C6       L9          NO
# 3            11     4440   62  ...               C2       L2          NO
# 4             2     4481  250  ...               C6       L9          NO
# 5            31     4440  500  ...               C6       L9          NO
# 6             1     4452   99  ...               C6       L9          NO
# ...         ...      ...  ...  ...              ...      ...         ...
# 15882         2     4460    5  ...              C13      L13          NO
# 15883         1     4493    3  ...              C13      L13          NO
# 15884         2     4493    8  ...              C12      L12          NO
# 15885         3     4493    1  ...               C7       L8         YES
# 15886         1     4493    8  ...              C12      L12          NO
#
#       Market Demand Quarter  Week Strateg Prod Strat Customer ABC  \
# 2                 3  2022Q4     1            0             No   C
# 3                 1  2022Q3     9            0             No   C
# 4                 3  2022Q4    12            0             No   C
# 5                 3  2022Q1     4            0             No   C
# 6                 3  2022Q3    10            0             No   C
# ...             ...     ...   ...          ...            ...  ..
# 15882             3  2022Q3     1            0             No   C
# 15883             3  2022Q3     1            0             No   B
# 15884             1  2022Q3     1            0             No   B
# 15885             1  2022Q3     1            0             No   B
# 15886             1  2022Q3     1            0             No   B
#
#       Customer Group
# 2               3986
# 3                684
# 4                521
# 5               3986
# 6               3986
# ...              ...
# 15882            720
# 15883            720
# 15884            684
# 15885            684
# 15886            684
#
# [14836 rows x 27 columns]>

# %%
#### Data Exploration / Visualisation 
###  some scatterplots  - set logaritm scale if necessary 
#g_rel.set(yscale="log",xscale="log") 

g_rel_unit_qty = sns.relplot(x="Qty", y="Unit Price", data=df_ml_dropna)
g_rel_unit_qty.set(yscale="log", xscale="log")
plt.title('Scatterplot of Qty vs Unit Price')


# After creating the scatter plot
plt.xscale('log')
plt.yscale('log')
# For a grid of scatter plots for all numerical variables
sns.pairplot(df)
plt.show()

# %%
## observe outliers #

# %%
#### records with value zero 
# Check values zero

# %%
### date treatment 
df_ml_tr['Planned Date'] = pd.to_datetime(df_ml_tr['Planned Date'])
df_ml_tr['Date'] = pd.to_datetime(df_ml_tr['Date'])
df_ml_tr['Delivered Date'] = pd.to_datetime(df_ml_tr['Delivered Date'])

# %%
### Values treatment 
df_ml_tr['Total Value '] = df_ml_tr['Total Value '].str.replace('$', '').str.replace(',', '')
df_ml_tr['Total Value '] = df_ml_tr['Total Value '].astype(float)

# %%
#### handling missing data 

#### impute the overall mean to zero prices

# %%
## check the average of prices by product --- what would be the best practice here?

# %%
#### handling missing data - Categories 


## impute zeros categories by most-frequent - ABC
### Has ABC any relationship to any other variables?  what would be the best practice here?

# %%
#### Encoding 
#### create categories for type cat columns 

#### encode all the object and convert as categories
### df_ml_cat.select_dtypes(include=['object']).columns

# %%
# Encode your data set to use Feature Selection

# %%
#### Feature Selection  
#### Select fields that contributes to the Return Prediction Model 

##using correlation 
### observe the correlation (heat map) what is possible to conclude?
## IS correlation the best method for Future Selection?

# %%
### select all relevant columns - example below ##
columns  = ['ABC','Customer Group','Strateg Prod','Strategic Sale','Group','Product','Order Source','Logistic Partner','Deposit','Replacement','Week']

## Using SelectKBest  
## get all the relevant fields recommented by the model

# %%
############### here is the current dataframe used by the ML Return Model 

### final dataset processed with columns example : 
#Customer Group 	Group 	Product 	Deposit 	Week

# %%
### by creating extra columns in your improved code (Feature engineering) , what will be the change in your dataframe, any relevant change? 
#### test this hipothesis  in your improved code
