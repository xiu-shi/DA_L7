# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
import seaborn as sns

# %%
cl1_df = np.random.normal(0,1,(20,1))
cl2_df = np.random.normal(3,1,(20,1))

# %%
### sample code generating random data
# np.random.normal(3,1,(20,1))

# %%
data = np.concatenate([cl1_df, cl2_df], axis = 0)
data
# Out:
# array([[ 0.58161824],
#        [-1.71750558],
#        [-0.38484338],
#        [ 0.40480293],
#        [ 1.74836688],
#        [ 0.79937826],
#        [ 1.48214782],
#        [ 0.28158688],
#        [ 0.52411315],
#        [ 1.11127798],
#        [-0.86803967],
#        [ 0.19448733],
#        [ 0.93346153],
#        [-1.37427536],
#        [-0.41120446],
#        [-0.7156022 ],
#        [ 2.72507449],
#        [-0.29609582],
#        [-0.69612197],
#        [-1.26544607],
#        [ 4.08876724],
#        [ 2.11531368],
#        [ 1.896634  ],
#        [ 2.68362266],
#        [ 3.42154549],
#        [ 3.06184798],
#        [ 3.30220735],
#        [ 2.65583404],
#        [ 3.02234241],
#        [ 3.90275537],
#        [ 3.04865101],
#        [ 1.03160494],
#        [ 1.07609857],
#        [ 3.28633107],
#        [ 3.37169337],
#        [ 3.24402145],
#        [ 3.34983433],
#        [ 1.06086321],
#        [ 2.89302657],
#        [ 1.04223972]])

# %%
distances = cdist(data,data,metric='euclidean').flatten()
distances
# Out:
# array([0.        , 2.29912383, 0.96646162, ..., 0.01862348, 1.85078684,
#        0.        ])

# %%
plt.scatter(data[:20],[0]*20, s=10, color='r')
plt.scatter(data[20:],[0]*20, s=10, color='b')
plt.title('1 dimension')
# Out:
# Text(0.5, 1.0, '1 dimension')

# %%
sns.histplot(distances, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
#### working with 2 dimensional data 
cl1_df = np.random.normal(0,1,(20,2))
cl2_df = np.random.normal(3,1,(20,2))
data = np.concatenate([cl1_df, cl2_df], axis = 0)

# %%
plt.scatter(data[:20,0],data[:20,1], s=10, color='r')
plt.scatter(data[20:,0], data[:20,1], s=10, color='b')
plt.title('2 Dimensions')
# Out:
# Text(0.5, 1.0, '2 Dimensions')

# %%
distances = cdist(data,data,metric='euclidean').flatten()
sns.histplot(distances, kde=True)
plt.title('2 Dimensions')
# Out:
# Text(0.5, 1.0, '2 Dimensions')

# %%
#### working with 3 dimensional data 
cl1_df = np.random.normal(0,1,(20,3))
cl2_df = np.random.normal(3,1,(20,3))
data = np.concatenate([cl1_df, cl2_df], axis = 0)

# %%
# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(data[:20,0], data[:20,1], data[:20,2], color = "red")
ax.scatter3D(data[20:,0], data[20:,1], data[20:,2], color = "blue")
plt.title('3 Dimensions')
# Out:
# Text(0.5, 0.92, '3 Dimensions')

# %%
distances = cdist(data,data,metric='euclidean').flatten()

sns.histplot(distances, kde=True)
plt.title('3 Dimensions')
# Out:
# Text(0.5, 1.0, '3 Dimensions')

# %%
#### working with 6 dimensional data 
cl1_df = np.random.normal(0,1,(20,6))
cl2_df = np.random.normal(3,1,(20,6))
data = np.concatenate([cl1_df, cl2_df], axis = 0)

# %%
distances = cdist(data,data,metric='euclidean').flatten()
sns.histplot(distances, kde=True)
plt.title('6 Dimensions')
# Out:
# Text(0.5, 1.0, '6 Dimensions')

# %%
#### working with 10 dimensional data 
cl1_df = np.random.normal(0,1,(20,10))
cl2_df = np.random.normal(3,1,(20,10))
data = np.concatenate([cl1_df, cl2_df], axis = 0)
data
# Out:
# array([[ 0.62286184, -1.53130882, -1.13712575,  0.16704144, -0.15541134,
#         -0.46220647, -0.30827511,  0.06198891, -1.05128295, -1.52742232],
#        [ 0.32029212,  0.12927361,  1.22806436,  0.66931402, -1.2890656 ,
#         -0.91836628, -0.76512078, -0.88254256,  0.7316106 , -0.85467903],
#        [ 0.79400475, -0.42728225,  1.38245251, -0.16181437,  1.1997668 ,
#         -0.02438519, -0.09380097, -0.88753105,  0.50779655, -0.13733893],
#        [-0.95618701,  0.04217425, -0.91580495, -0.03393132,  0.58236618,
#         -0.43491223,  0.1686898 , -1.08154757, -1.86670841, -0.33686439],
#        [ 0.18814271, -0.32909966,  0.77506826,  0.686183  , -0.20032083,
#         -1.30932328,  0.69208877, -0.81367539, -1.17590804, -0.12294656],
#        [-0.36771247,  0.02764609,  0.51596806, -1.76732987, -2.41350927,
#          0.32641503,  0.6739872 , -0.49267119, -2.54423032, -1.44607945],
#        [ 0.78470811, -0.80542195,  1.75716251, -0.25299421, -1.1926155 ,
# ...

# %%
distances = cdist(data,data,metric='euclidean').flatten()
sns.histplot(distances, kde=True)
plt.title('10 Dimensions')
# Out:
# Text(0.5, 1.0, '10 Dimensions')

# %%
#### working with 20 dimensional data 
cl1_df = np.random.normal(0,1,(20,30))
cl2_df = np.random.normal(3,1,(20,30))
data = np.concatenate([cl1_df, cl2_df], axis = 0)
data
# Out:
# array([[-0.44159662,  0.78792118, -0.05754689, ...,  0.40719448,
#          2.15197964,  0.42085669],
#        [-0.46216396,  0.41002039, -0.48055289, ...,  0.08751592,
#         -0.47793496, -0.12250919],
#        [ 1.02523534,  1.9727977 ,  1.53524587, ...,  0.86486191,
#         -0.30835461, -0.29964254],
#        ...,
#        [ 3.73194806,  1.27606855,  2.29048301, ...,  2.30133673,
#          0.7399306 ,  2.50495796],
#        [ 2.63567097,  2.74189002,  3.07180537, ...,  2.67782879,
#          3.98889588,  1.03359492],
#        [ 3.23023784,  4.25428351,  2.30254633, ...,  3.55589938,
#          4.01096915,  4.18492176]])

# %%
distances = cdist(data,data,metric='euclidean').flatten()

sns.histplot(distances, kde=True)
plt.title('30 Dimensions')
# Out:
# Text(0.5, 1.0, '30 Dimensions')
