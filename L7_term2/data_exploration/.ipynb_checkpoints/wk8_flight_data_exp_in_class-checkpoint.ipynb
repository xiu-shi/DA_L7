# %%
import pandas as pd
import seaborn as sns
import datetime
import matplotlib.pyplot as plt
# patterns
import glob

# %%
filepaths=glob.glob("/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/*.csv")
filepaths
# Out:
# ['/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/LH2519_33f56eb8.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/FR126_33f8ab4a.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/LH2519_33f2a369.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/EI3258_33ec2db7.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/LH2519_33ef755b.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/LH2519_33ec0d89.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/FR126_33f29c2f.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/LH2519_33f86f4a.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/EI3258_33f5708b.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/FR126_33f56293.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/FR126_33ec127c.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/EI3258_33f86dc5.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/FR126_33ef8d93.csv',
#  '/Users/eupirate/Documents/DA_L7/L7_term2/data_exploration/wk8_in_class/EI3258_33ef7021.csv']

# %%
## create an empty dataframe
df_airlines=[]

for file in filepaths:
    df_airlines.append(pd.read_csv(file))

df_flight=pd.concat(df_airlines)
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5836 entries, 0 to 296
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  5836 non-null   int64
#  1   UTC        5836 non-null   object
#  2   Callsign   5836 non-null   object
#  3   Position   5836 non-null   object
#  4   Altitude   5836 non-null   int64
#  5   Speed      5836 non-null   int64
#  6   Direction  5836 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 364.8+ KB

# %%
df_flight.describe(include="all")
# Out:
#            Timestamp                   UTC Callsign             Position  \
# count   5.836000e+03                  5836     5836                 5836
# unique           NaN                  5592        3                 5822
# top              NaN  2024-02-09T18:49:50Z   DLH2MH  53.435265,-6.245909
# freq             NaN                     3     2229                    2
# mean    1.707603e+09                   NaN      NaN                  NaN
# std     1.254347e+05                   NaN      NaN                  NaN
# min     1.707415e+09                   NaN      NaN                  NaN
# 25%     1.707504e+09                   NaN      NaN                  NaN
# 50%     1.707595e+09                   NaN      NaN                  NaN
# 75%     1.707681e+09                   NaN      NaN                  NaN
# max     1.707771e+09                   NaN      NaN                  NaN
#
#             Altitude        Speed    Direction
# count    5836.000000  5836.000000  5836.000000
# unique           NaN          NaN          NaN
# top              NaN          NaN          NaN
# freq             NaN          NaN          NaN
# mean    11345.771933   224.058602   148.295922
# std     12638.990997   151.689529    95.522475
# min         0.000000     0.000000     1.000000
# 25%      1175.000000   108.000000    83.000000
# 50%      6262.500000   231.000000   119.000000
# 75%     15000.000000   332.000000   239.000000
# max     39050.000000   523.000000   359.000000

# %%
df_flight
# Out:
#       Timestamp                   UTC Callsign             Position  Altitude  \
# 0    1707674144  2024-02-11T17:55:44Z   DLH2MH  53.426582,-6.246919         0
# 1    1707674200  2024-02-11T17:56:40Z   DLH2MH   53.426743,-6.24712         0
# 2    1707674225  2024-02-11T17:57:05Z   DLH2MH  53.426949,-6.247297         0
# 3    1707674253  2024-02-11T17:57:33Z   DLH2MH  53.427166,-6.247283         0
# 4    1707674295  2024-02-11T17:58:15Z   DLH2MH  53.426792,-6.247161         0
# ..          ...                   ...      ...                  ...       ...
# 292  1707505079  2024-02-09T18:57:59Z  EAI58EH  55.947784,-3.367696         0
# 293  1707505087  2024-02-09T18:58:07Z  EAI58EH  55.947598,-3.367481         0
# 294  1707505093  2024-02-09T18:58:13Z  EAI58EH   55.94751,-3.367206         0
# 295  1707505097  2024-02-09T18:58:17Z  EAI58EH  55.947514,-3.366988         0
# 296  1707505102  2024-02-09T18:58:22Z  EAI58EH  55.947514,-3.366752         0
#
#      Speed  Direction
# 0        0        146
# 1        2        154
# 2        2        188
# 3        1        230
# 4        1        244
# ..     ...        ...
# 292      6        168
# 293      6        146
# 294      6        112
# 295      7         95
# 296      5         92
#
# [5836 rows x 7 columns]

# %%
## adding more features Date and Time
## import datetime
df_flight["Date"]=pd.to_datetime(df_flight["UTC"]).dt.date
df_flight["Time"]=pd.to_datetime(df_flight["UTC"]).dt.time

# %%
df_flight
# Out:
#       Timestamp                   UTC Callsign             Position  Altitude  \
# 0    1707674144  2024-02-11T17:55:44Z   DLH2MH  53.426582,-6.246919         0
# 1    1707674200  2024-02-11T17:56:40Z   DLH2MH   53.426743,-6.24712         0
# 2    1707674225  2024-02-11T17:57:05Z   DLH2MH  53.426949,-6.247297         0
# 3    1707674253  2024-02-11T17:57:33Z   DLH2MH  53.427166,-6.247283         0
# 4    1707674295  2024-02-11T17:58:15Z   DLH2MH  53.426792,-6.247161         0
# ..          ...                   ...      ...                  ...       ...
# 292  1707505079  2024-02-09T18:57:59Z  EAI58EH  55.947784,-3.367696         0
# 293  1707505087  2024-02-09T18:58:07Z  EAI58EH  55.947598,-3.367481         0
# 294  1707505093  2024-02-09T18:58:13Z  EAI58EH   55.94751,-3.367206         0
# 295  1707505097  2024-02-09T18:58:17Z  EAI58EH  55.947514,-3.366988         0
# 296  1707505102  2024-02-09T18:58:22Z  EAI58EH  55.947514,-3.366752         0
#
#      Speed  Direction        Date      Time
# 0        0        146  2024-02-11  17:55:44
# 1        2        154  2024-02-11  17:56:40
# 2        2        188  2024-02-11  17:57:05
# 3        1        230  2024-02-11  17:57:33
# 4        1        244  2024-02-11  17:58:15
# ..     ...        ...         ...       ...
# 292      6        168  2024-02-09  18:57:59
# 293      6        146  2024-02-09  18:58:07
# 294      6        112  2024-02-09  18:58:13
# 295      7         95  2024-02-09  18:58:17
# 296      5         92  2024-02-09  18:58:22
#
# [5836 rows x 9 columns]

# %%
df_flight.isnull().sum()
# Out:
# Timestamp    0
# UTC          0
# Callsign     0
# Position     0
# Altitude     0
# Speed        0
# Direction    0
# Date         0
# Time         0
# dtype: int64

# %%
df_flight[["Lat","Long"]]=df_flight["Position"].str.split(",").apply(pd.Series).astype(float)
df_flight
# Out:
#       Timestamp                   UTC Callsign             Position  Altitude  \
# 0    1707674144  2024-02-11T17:55:44Z   DLH2MH  53.426582,-6.246919         0
# 1    1707674200  2024-02-11T17:56:40Z   DLH2MH   53.426743,-6.24712         0
# 2    1707674225  2024-02-11T17:57:05Z   DLH2MH  53.426949,-6.247297         0
# 3    1707674253  2024-02-11T17:57:33Z   DLH2MH  53.427166,-6.247283         0
# 4    1707674295  2024-02-11T17:58:15Z   DLH2MH  53.426792,-6.247161         0
# ..          ...                   ...      ...                  ...       ...
# 292  1707505079  2024-02-09T18:57:59Z  EAI58EH  55.947784,-3.367696         0
# 293  1707505087  2024-02-09T18:58:07Z  EAI58EH  55.947598,-3.367481         0
# 294  1707505093  2024-02-09T18:58:13Z  EAI58EH   55.94751,-3.367206         0
# 295  1707505097  2024-02-09T18:58:17Z  EAI58EH  55.947514,-3.366988         0
# 296  1707505102  2024-02-09T18:58:22Z  EAI58EH  55.947514,-3.366752         0
#
#      Speed  Direction        Date      Time        Lat      Long
# 0        0        146  2024-02-11  17:55:44  53.426582 -6.246919
# 1        2        154  2024-02-11  17:56:40  53.426743 -6.247120
# 2        2        188  2024-02-11  17:57:05  53.426949 -6.247297
# 3        1        230  2024-02-11  17:57:33  53.427166 -6.247283
# 4        1        244  2024-02-11  17:58:15  53.426792 -6.247161
# ..     ...        ...         ...       ...        ...       ...
# 292      6        168  2024-02-09  18:57:59  55.947784 -3.367696
# 293      6        146  2024-02-09  18:58:07  55.947598 -3.367481
# 294      6        112  2024-02-09  18:58:13  55.947510 -3.367206
# 295      7         95  2024-02-09  18:58:17  55.947514 -3.366988
# 296      5         92  2024-02-09  18:58:22  55.947514 -3.366752
#
# [5836 rows x 11 columns]

# %%
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5836 entries, 0 to 296
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  5836 non-null   int64
#  1   UTC        5836 non-null   object
#  2   Callsign   5836 non-null   object
#  3   Position   5836 non-null   object
#  4   Altitude   5836 non-null   int64
#  5   Speed      5836 non-null   int64
#  6   Direction  5836 non-null   int64
#  7   Date       5836 non-null   object
#  8   Time       5836 non-null   object
#  9   Lat        5836 non-null   float64
#  10  Long       5836 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 547.1+ KB

# %%
sns.pairplot(df_flight,hue="Callsign")

# %%
sns.pairplot(df_flight[df_flight['Callsign'].isin(['EAI58EH','RYR99HM'])], hue = 'Callsign')

# %%
df_flight.describe(include="all")
# Out:
#            Timestamp                   UTC Callsign             Position  \
# count   5.836000e+03                  5836     5836                 5836
# unique           NaN                  5592        3                 5822
# top              NaN  2024-02-09T18:49:50Z   DLH2MH  53.435265,-6.245909
# freq             NaN                     3     2229                    2
# mean    1.707603e+09                   NaN      NaN                  NaN
# std     1.254347e+05                   NaN      NaN                  NaN
# min     1.707415e+09                   NaN      NaN                  NaN
# 25%     1.707504e+09                   NaN      NaN                  NaN
# 50%     1.707595e+09                   NaN      NaN                  NaN
# 75%     1.707681e+09                   NaN      NaN                  NaN
# max     1.707771e+09                   NaN      NaN                  NaN
#
#             Altitude        Speed    Direction        Date      Time  \
# count    5836.000000  5836.000000  5836.000000        5836      5836
# unique           NaN          NaN          NaN           5      4356
# top              NaN          NaN          NaN  2024-02-11  18:18:23
# freq             NaN          NaN          NaN        1448         6
# mean    11345.771933   224.058602   148.295922         NaN       NaN
# std     12638.990997   151.689529    95.522475         NaN       NaN
# min         0.000000     0.000000     1.000000         NaN       NaN
# 25%      1175.000000   108.000000    83.000000         NaN       NaN
# 50%      6262.500000   231.000000   119.000000         NaN       NaN
# 75%     15000.000000   332.000000   239.000000         NaN       NaN
# max     39050.000000   523.000000   359.000000         NaN       NaN
#
#                 Lat         Long
# count   5836.000000  5836.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean      52.382343    -0.699584
# std        2.198600     6.038031
# min       48.315868    -6.500514
# 25%       51.108066    -6.152444
# 50%       53.262371    -2.976380
# 75%       53.474433     0.156592
# max       56.057831    12.148928

# %%
df_flight_cat=df_flight.copy()

# %%
df_flight_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5836 entries, 0 to 296
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  5836 non-null   int64
#  1   UTC        5836 non-null   object
#  2   Callsign   5836 non-null   object
#  3   Position   5836 non-null   object
#  4   Altitude   5836 non-null   int64
#  5   Speed      5836 non-null   int64
#  6   Direction  5836 non-null   int64
#  7   Date       5836 non-null   object
#  8   Time       5836 non-null   object
#  9   Lat        5836 non-null   float64
#  10  Long       5836 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 547.1+ KB

# %%
catcol=df_flight_cat.select_dtypes(include=["object"]).columns

# %%
catcol
# Out:
# Index(['UTC', 'Callsign', 'Position', 'Date', 'Time'], dtype='object')

# %%
for col in catcol:
    df_flight_cat[col]=df_flight_cat[col].astype("category").cat.codes

# %%
df_flight_cat
# Out:
#       Timestamp   UTC  Callsign  Position  Altitude  Speed  Direction  Date  \
# 0    1707674144  3059         0      3363         0      0        146     3
# 1    1707674200  3061         0      3375         0      2        154     3
# 2    1707674225  3063         0      3389         0      2        188     3
# 3    1707674253  3065         0      3404         0      1        230     3
# 4    1707674295  3067         0      3378         0      1        244     3
# ..          ...   ...       ...       ...       ...    ...        ...   ...
# 292  1707505079  1645         1      5543         0      6        168     1
# 293  1707505087  1647         1      5536         0      6        146     1
# 294  1707505093  1648         1      5530         0      6        112     1
# 295  1707505097  1649         1      5532         0      7         95     1
# 296  1707505102  1650         1      5531         0      5         92     1
#
#      Time        Lat      Long
# 0     126  53.426582 -6.246919
# 1     133  53.426743 -6.247120
# 2     135  53.426949 -6.247297
# 3     137  53.427166 -6.247283
# 4     139  53.426792 -6.247161
# ..    ...        ...       ...
# 292  2044  55.947784 -3.367696
# 293  2049  55.947598 -3.367481
# 294  2052  55.947510 -3.367206
# 295  2055  55.947514 -3.366988
# 296  2058  55.947514 -3.366752
#
# [5836 rows x 11 columns]
