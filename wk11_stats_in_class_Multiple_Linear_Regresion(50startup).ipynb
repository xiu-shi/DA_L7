# %%
##IMPORTING LIBRARIES
import pandas as pd
import statistics as stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#IMPORTING DATASET
# Importing the dataset
dataset = pd.read_csv('/Users/janet.xuishi/Documents/DA_L7/wk3_sta_50_Startups.csv')
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
#
#    Unnamed: 5 Administration.1     Unnamed: 7
# 0         NaN              NaN            NaN
# 1         NaN             Mean  121344.639600
# 2         NaN   Standard Error    3962.315664
# 3         NaN           Median  122699.795000
# 4         NaN             Mode            NaN

# %%
#Pairplot

sns.pairplot(dataset)
# Out:
# /Users/janet.xuishi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/janet.xuishi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/janet.xuishi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
#We need to define the variables

X = dataset.iloc[:,2:4].values
y = dataset.iloc[:, 1].values

# %%
# We need to split the data into training and testing set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
#We train the model for Linear Regression

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 5
#       3 from sklearn.linear_model import LinearRegression
#       4 regressor = LinearRegression()
# ----> 5 regressor.fit(X_train, y_train)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
# ...

# %%
y_pred = regressor.predict(X_test)

# %%
#We calculate the accuracy of this model (r^2)

regressor.score(X_train, y_train)

# %% [markdown]
# As r^2 is 0.92 we can say that 92% of the changes in the tv sales will depend on the ads that are placed in the TV and the Newspapers.

# %%
#We can make predictions

#We need to consider that we have 2 variables. We want to know how much income we will receive for the sales if we spend 6 k in TV ads and 6.5 k in newspapers ads 
print(regressor.predict([[6,6.5]]))

# %% [markdown]
# We expect to have 7 million USD in income if we post ads in TV and newspaper with the provided values.
