# %%
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
#pip install notebook-as-pdf

# %%
#!pyppeteer-install

# %%
#pip install pyppeteer

# %% [markdown]
# ### Introduction
# This is a paragraph
# - Point 1
# - Point 2
# - Point 3

# %%
#pip install nbconvert

# %%
#pip install voila

# %% [markdown]
# ![favicon.jpg](attachment:favicon.jpg)
