# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statistics as stats
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/Users/janet.xuishi/Documents/DA_L7/wk11_stats_in_class_tvsales.csv")

# %%
dataset.head()
# Out:
#    Location  Sales (in millions dollars)  TV Ads (in thousands of dollars)  \
# 0         1                         9.73                                 0
# 1         2                        11.19                                 0
# 2         3                         8.75                                 5
# 3         4                         6.25                                 5
# 4         5                         9.10                                10
#
#    Newspaper Ads (in thousands of dollars)
# 0                                       20
# 1                                       20
# 2                                        5
# 3                                        5
# 4                                       10

# %%
#pairplot

sns.pairplot(dataset)
# Out:
# /Users/janet.xuishi/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#define the variables
#x column 2 - 3
# y - sales

X = dataset.iloc[:,2:4].values 
y = dataset.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20, random_state = 0)

# %%
# training the model for linear regression

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
# calc the accuracy of this modle (r squre 2)
regressor.score(X_train, y_train)
# Out:
# 0.9266521300481103

# %% [markdown]
# As r sq 2 is 0.92, we can say the 92% of the changes in the TV

# %%
# we can make predictions, we have 2 variables. We want to know how much income we will receive for the sales if we spend 6k in TV ads, 6.5K in newspaper ads.
print(regressor.predict([[6,6.5]]))
# Out:
# [7.81579231]

# %%
#we expect to have 7M usd in income if we post ads in TV and newspaper

# %%
print(regressor.predict([[6,10]]))
# Out:
# [8.55763077]
